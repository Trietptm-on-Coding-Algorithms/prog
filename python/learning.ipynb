# %%
import numpy as np

# %%
a = np.array([1,2,3,5]) #creates a np array from python array
a = np.arange(1000) #creates a np array using args
#np.lookfor('log') # searchs numpy docs

# %%
# !cat population.txt
# Out:
# # year	hare	lynx	carrot
# 1900	30e3	4e3	48300
# 1901	47.2e3	6.1e3	48200
# 1902	70.2e3	9.8e3	41500
# 1903	77.4e3	35.2e3	38200
# 1904	36.3e3	59.4e3	40600
# 1905	20.6e3	41.7e3	39800
# 1906	18.1e3	19e3	38600
# 1907	21.4e3	13e3	42300
# 1908	22e3	8.3e3	44500
# 1909	25.4e3	9.1e3	42100
# 1910	27.1e3	7.4e3	46000
# 1911	40.3e3	8e3	46800
# 1912	57e3	12.3e3	43800
# 1913	76.6e3	19.5e3	40900
# 1914	52.3e3	45.7e3	39400
# 1915	19.5e3	51.1e3	39000
# 1916	11.2e3	29.7e3	36700
# 1917	7.6e3	15.8e3	41800
# 1918	14.6e3	9.7e3	43300
# 1919	16.2e3	10.1e3	41300
# 1920	24.7e3	8.6e3	47300

# %%
import numpy as np
from matplotlib import pyplot as plt
# %pylab inline
data = np.loadtxt('population.txt')
year, hares, lynxes, carrots = data.T
plt.axes([0.2, 0.1, 0.5, 0.8])
plt.plot(year, hares, year, lynxes, year, carrots)
plt.legend(['Hare', 'Lynx', 'Carrot'], loc=(1.05, 0.5))
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
populations = data[:, 1:]
#mean, std, column that is the max per year
populations.mean(axis=0), populations.std(axis=0), np.argmax(populations, axis=1)
# Out:
# (array([ 34080.95238095,  20166.66666667,  42400.        ]),
#  array([ 20897.90645809,  16254.59153691,   3322.50622558]),
#  array([2, 2, 0, 0, 1, 1, 2, 2, 2, 2, 2, 2, 0, 0, 0, 1, 2, 2, 2, 2, 2]))
