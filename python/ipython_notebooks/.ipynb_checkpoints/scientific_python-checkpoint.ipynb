# %%
#ipython tricks
import numpy as np
np.arange?
#get documentation

# %%
# %cd ~
# %timeit x = 10
# %debug
# %quickref
# %magic
# Out:
# /home/leeeee
# 10000000 loops, best of 3: 25.7 ns per loop
# > <ipython-input-1-126e7762767d>(1)<module>()
# ----> 1 a = np.random.random_integers(0, 20, 15)
#       2 a
# ipdb>
# ipdb> help
# Documented commands (type help <topic>):
# ========================================
# EOF    bt         cont      enable  jump  pdef    psource  run      unt
# a      c          continue  exit    l     pdoc    q        s        until
# alias  cl         d         h       list  pfile   quit     step     up
# args   clear      debug     help    n     pinfo   r        tbreak   w
# b      commands   disable   ignore  next  pinfo2  restart  u        whatis
# break  condition  down      j       p     pp      return   unalias  where
#
# Miscellaneous help topics:
# ==========================
# exec  pdb
#
# Undocumented commands:
# ======================
# retval  rv
# ipdb> quit()

# %%
alias
# Out:
# Total number of aliases: 12
# [('cat', 'cat'),
#  ('cp', 'cp -i'),
#  ('ldir', 'ls -F -o --color %l | grep /$'),
#  ('lf', 'ls -F -o --color %l | grep ^-'),
#  ('lk', 'ls -F -o --color %l | grep ^l'),
#  ('ll', 'ls -F -o --color'),
#  ('ls', 'ls -F --color'),
#  ('lx', 'ls -F -o --color %l | grep ^-..x'),
#  ('mkdir', 'mkdir'),
#  ('mv', 'mv -i'),
#  ('rm', 'rm -i'),
#  ('rmdir', 'rmdir')]

# %%
def variable_args(*args, **kwargs):
    """This function demonstrates args variables
    """
    print 'args is ', args
    print 'kwargs is ', kwargs

# %%
import os
os.getcwd()
os.listdir(os.curdir)
# Out:
# ['Desktop',
#  '.ivy2',
#  '.clion10',
#  '.gnome2_private',
#  '.npm',
#  '.Xauthority',
#  '.bashrc',
#  '.ycm_extra_conf.py',
#  '.node_packages',
#  '.ssh',
#  '.gksu.lock',
#  'IdeaProjects',
#  '.ICEauthority',
#  'Pictures',
#  '.pgpass',
#  '.node-gyp',
#  '.aqemu',
#  '.vim',
#  'eclipse',
#  '.python_history',
#  '.subversion',
#  '.bash_history',
#  '.cinnamon',
#  '.scala_history',
#  '.sbt',
#  'Music',
#  '.eclipse',
#  '.pki',
#  '.gconf',
#  '.gitconfig',
#  '.gnome2',
#  '.cache',
#  '.ghc',
#  '.ycm_extra_conf.pyc',
#  'Templates',
#  '.viminfo',
#  'pgadmin.log',
#  '.lesshst',
#  '.IdeaIC14',
#  '.bash_logout',
#  '.v8flags.4.5.103.33.leeeee.json',
#  'Videos',
#  '.IntelliJIdea14',
#  '.babel.json',
#  '.mozilla',
#  '.dbus',
#  '.vimrc',
#  '.linuxmint',
#  '.dmrc',
#  '.npmrc',
#  '.v8flags.3.28.71.19.leeeee.json',
#  '.m2',
#  'Public',
#  '.local',
#  '.xsession-errors',
#  '.java',
#  '.gradle',
#  '.gnome',
#  '.profile',
#  'Downloads',
#  'workspace',
#  'ClionProjects',
#  '.pgadmin3',
#  '.android',
#  '.config',
#  'Documents']

# %%
a = np.array([1,2,3,4,5]) # converts python array to np array
a = np.arange(1000) # creates a list of 1000 numbers
np.lookfor('createee array') # search documentation
b = np.array([[1,2,3],[3,4,5]]) # 2 d
b.ndim
b.shape
len(b) #returns size of first dimension
c = np.linspace(0,1,6)
np.linspace?
a = np.ones((3,3))
a = np.zeros((2,2))
a = np.eye(3)
a = np.diag(np.arange(5))
a = np.random.rand(4) #uniform
a = np.random.rand(4) #gaussian
np.random.seed(1234)
a.dtype
# Out:
# Search results for 'createee array'
# -----------------------------------
# Nothing found.
# dtype('float64')

# %%
# %pylab inline
import matplotlib.pyplot as plt
x = np.linspace(0,3,20)
y = np.linspace(0,9,20)
plt.plot(x,y)
plt.show()
plt.plot(x,y, 'o')
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
image = np.random.rand(30,30)
plt.imshow(image, cmap=plt.cm.hot)
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x7fe7b01e7ea8>

# %%
a = np.arange(10)
a[2:9:3] #[start:end:step]
a[::-1] #reverse
a[:4] #until 4
a[::2] #every other
a[3:] #everything after 3
# Out:
# array([3, 4, 5, 6, 7, 8, 9])

# %%
a = np.random.random_integers(0, 20, 15)
mask = ( a % 3 == 0)
a[mask]
# Out:
# array([ 6,  3,  0,  3, 15,  0,  3,  3])

# %%
c = np.ones((3,3))
c.dot(c)
x = np.triu(np.ones((3,3)), 0)
np.array_equal(c,c)
# Out:
# True

# %%
y = np.array([1,2,3,4])
np.sum(y)
x.sum(axis=0) #y axis
x.sum(axis=1) #x axis

y.max()
y.min()
y.argmin()
y.argmax()
# Out:
# array([ 3.,  2.,  1.])
